# %%
import os
import scanpy as sc

sc.settings.verbosity = 0
sc.settings.set_figure_params(dpi=80, facecolor="white", frameon=False)

# %%
os.chdir('/Users/juzizhenbutaitian/Desktop/python_sc')

# %%
adata = sc.read("s4d8_dimensionality_reduction.h5ad")

# %%
sc.pp.neighbors(adata, n_pcs=30)
sc.tl.umap(adata)

# %%
sc.tl.leiden(adata)
# Out:
# /var/folders/mg/ly_z2yvn79q4dl8pmm2ws74h0000gn/T/ipykernel_48751/3467744858.py:1: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata)

# %%
sc.tl.leiden(adata, key_added="leiden_res0_25", resolution=0.25)
sc.tl.leiden(adata, key_added="leiden_res0_5", resolution=0.5)
sc.tl.leiden(adata, key_added="leiden_res1", resolution=1.0)

# %%
sc.pl.umap(
    adata,
    color=["leiden_res0_25", "leiden_res0_5", "leiden_res1"],
    legend_loc="on data",
)
